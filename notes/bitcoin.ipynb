# %% [markdown]
# # Keys

# %%
# https://ofek.dev/bit/guide/keys.html
from bit import Key, PrivateKey, PrivateKeyTestnet

# %%
Key == PrivateKey
# Out:
# True

# %%
dir(Key) == dir(PrivateKeyTestnet)
# Out:
# True

# %%
key = Key()

# %%
from bit import MultiSig

# %%
key1 = Key()
key2 = Key()
multisig = MultiSig(key1, {key1.public_key, key2.public_key}, 2)

# %%
key.public_point
# Out:
# Point(x=87067316446722661162685939904892975126129487272881561293499536587739874770766, y=78387220633488262401633668893552909248203386329645242742866562714701895184977)

# %%
key.public_key
# Out:
# b'\x03\xc0~Z\xd0\xe1\\\x81s\xae\xe1\xce`\xa3u\n_\xcda\x83qT\xd9\x81A\xbaPP\xae(\x1c\xbfN'

# %%
key.address
# Out:
# '1DzJbawCGHtRhu2ZRZQL1miu2EkaHdr1j6'

# %%
key.segwit_address
# Out:
# '3Db97Z92G7Tpexp5ftVMtWULQogQRUfCHR'

# %%
key = Key('L3jsepcttyuJK3HKezD4qqRKGtwc8d2d1Nw6vsoPDX9cMcUxqqMv')
key.to_wif()
# Out:
# 'L3jsepcttyuJK3HKezD4qqRKGtwc8d2d1Nw6vsoPDX9cMcUxqqMv'

# %% [markdown]
# # Network

# %%
from bit import PrivateKeyTestnet

# %%
key = PrivateKeyTestnet('L3jsepcttyuJK3HKezD4qqRKGtwc8d2d1Nw6vsoPDX9cMcUxqqMv')
key.balance
# Out:
# 0

# %%
key.get_balance('btc')
# Out:
# '0'

# %%
key.balance_as('usd')
# Out:
# '0'

# %%
import os
from bit.network import NetworkAPI

# %%
USER = os.getenv('BITCOIN_USER')
PASSWORD = os.getenv('BITCOIN_PASSWORD')

# %%
node = NetworkAPI.connect_to_node(USER, PASSWORD, host='localhost', port=8332)

# %%
key.segwit_address
# Out:
# '2MshDmGtwW3aV8Nr3B3PSvmo5o8yqhwJFKZ'

# %%
# https://bitcoincore.org/en/doc/27.0.0/rpc/wallet/importaddress/
node.importaddress(key.segwit_address, 'ipynb', False)
# Out:
# ---------------------------------------------------------------------------
# BitcoinNodeException                      Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 node.importaddress(key.segwit_address, 'ipynb', False)
#
# File ~/miniconda3/envs/ai/lib/python3.10/site-packages/bit/network/services.py:103, in RPCMethod.__call__(self, *args)
#     101 responseJSON = response.json()
#     102 if "error" in responseJSON and responseJSON["error"] is not None:
# --> 103     raise BitcoinNodeException("Error in RPC call: " + str(responseJSON["error"]))
#     104 return responseJSON["result"]
#
# BitcoinNodeException: Error in RPC call: {'code': -4, 'message': 'Only legacy wallets are supported by this command'}
